# %%
from attention import AttentionLayer

# %%
import numpy as np  
import pandas as pd 
import re           
from bs4 import BeautifulSoup 
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("/home/rohit/projects/text_summarization/amazon_food_review/Reviews.csv",nrows=100000)

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary  \
# 0  Good Quality Dog Food
# 1      Not as Advertised
# 2  "Delight" says it all
# 3         Cough Medicine
# 4            Great taffy
#
#                                                                                                                                                                                                       Text
# 0  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3  If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                             Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.

# %%
data.drop_duplicates(subset=['Text'],inplace=True)  #dropping duplicates
data.dropna(axis=0,inplace=True)   #dropping na

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %%
data['Text'][:10]
# Out:
# 0    I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1             Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2    This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3    If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                               Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# 5    I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there wa...
# 6    This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, ...
# 7                                                               This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!
# 8                                                                        Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too
# 9                                                                  This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.
# Name: Text, dtype: object

# %%
stop_words = set(stopwords.words('english')) 

def text_cleaner(text,num):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# %%
#call the function
cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t,0))

# %%
cleaned_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
data['Summary'][:10]
# Out:
# 0                            Good Quality Dog Food
# 1                                Not as Advertised
# 2                            "Delight" says it all
# 3                                   Cough Medicine
# 4                                      Great taffy
# 5                                       Nice Taffy
# 6    Great!  Just as good as the expensive brands!
# 7                           Wonderful, tasty taffy
# 8                                       Yay Barley
# 9                                 Healthy Dog Food
# Name: Summary, dtype: object

# %%
#call the function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(text_cleaner(t,1))

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

#Call the above function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(summary_cleaner(t))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
data['cleaned_summary'] = data['cleaned_summary'].apply(lambda x : '_START_ '+ x + ' _END_')

# %%
data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary

# %%
data.replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
for i in range(5):
    print("Review:",data['cleaned_text'][i])
    print("Summary:",data['cleaned_summary'][i])
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Summary: _START_ good quality dog food  _END_
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Summary: _START_ not as advertised  _END_
#
#
# Review: confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# Summary: _START_ delight says it all  _END_
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Summary: _START_ cough medicine  _END_
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Summary: _START_ great taffy  _END_

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %%
cnt=0
for i in data['cleaned_summary']:
    if(len(i.split())<=8):
        cnt=cnt+1
print(cnt/len(data['cleaned_summary']))
# Out:
# 0.9424907471335922

# %%
max_text_len=80 
max_summary_len=10

# %%
cleaned_text =np.array(data['cleaned_text'])
cleaned_summary=np.array(data['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
df=pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['summary']),test_size=0.1,random_state=0,shuffle=True)

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(data['cleaned_text'],data['cleaned_summary'],test_size=0.1,random_state=0,shuffle=True)

# %% [markdown]
# ## Review Tokenizer

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 64.72356491835606
# Total Coverage of rare words: 1.7506273812883235

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post') 
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) +1

# %% [markdown]
# ## Summary Tokenizer

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 76.24881441669301
# Total Coverage of rare words: 4.052571496345495

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) +1

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

# %%
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (71019, 71019)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %% [markdown]
# ## Model Building

# %%
from keras import backend as K 
K.clear_session()

latent_dim = 300
embedding_dim=100

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 80, 100)      1467000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 80, 300), (N 481200      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 80, 300), (N 721200      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    300600      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 80, 300), (N 721200      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 300),  481200      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 300),  180300      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 600)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 3006)   1806606     concat_layer[0][0]
# ==================================================================================================
# Total params: 6,159,306
# Trainable params: 6,159,306
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=512, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 137/137 [==============================] - 71s 478ms/step - loss: 2.8392 - val_loss: 2.5733
# Epoch 2/50
# 137/137 [==============================] - 65s 477ms/step - loss: 2.4415 - val_loss: 2.3753
# Epoch 3/50
# 137/137 [==============================] - 65s 477ms/step - loss: 2.3322 - val_loss: 2.2695
# Epoch 4/50
# 137/137 [==============================] - 66s 479ms/step - loss: 2.2267 - val_loss: 2.1669
# Epoch 5/50
# 137/137 [==============================] - 66s 478ms/step - loss: 2.1238 - val_loss: 2.0910
# Epoch 6/50
# 137/137 [==============================] - 66s 480ms/step - loss: 2.0399 - val_loss: 2.0388
# Epoch 7/50
# 137/137 [==============================] - 66s 480ms/step - loss: 1.9751 - val_loss: 2.0006
# Epoch 8/50
# 137/137 [==============================] - 66s 479ms/step - loss: 1.9218 - val_loss: 1.9594
# Epoch 9/50
# 137/137 [==============================] - 66s 479ms/step - loss: 1.8759 - val_loss: 1.9361
# Epoch 10/50
# 137/137 [==============================] - 66s 480ms/step - loss: 1.8356 - val_loss: 1.9208
# Epoch 11/50
# 137/137 [==============================] - 66s 481ms/step - loss: 1.7982 - val_loss: 1.9043
# Epoch 12/50
# 137/137 [==============================] - 66s 480ms/step - loss: 1.7641 - val_loss: 1.8888
# Epoch 13/50
# 137/137 [==============================] - 66s 480ms/step - loss: 1.7321 - val_loss: 1.8790
# Epoch 14/50
# 137/137 [==============================] - 66s 480ms/step - loss: 1.7018 - val_loss: 1.8752
# Epoch 15/50
# 137/137 [==============================] - 66s 480ms/step - loss: 1.6730 - val_loss: 1.8694
# Epoch 16/50
# 137/137 [==============================] - 66s 480ms/step - loss: 1.6461 - val_loss: 1.8631
# Epoch 17/50
# 137/137 [==============================] - 66s 481ms/step - loss: 1.6216 - val_loss: 1.8618
# Epoch 18/50
# 137/137 [==============================] - 66s 480ms/step - loss: 1.5973 - val_loss: 1.8565
# Epoch 19/50
# 137/137 [==============================] - 66s 482ms/step - loss: 1.5739 - val_loss: 1.8518
# Epoch 20/50
# 137/137 [==============================] - 66s 481ms/step - loss: 1.5512 - val_loss: 1.8547
# Epoch 21/50
# 137/137 [==============================] - 66s 483ms/step - loss: 1.5299 - val_loss: 1.8582
# Epoch 00021: early stopping

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: vegetarian almost years love taco filling used make straight traditional tacos enchiladas well taco pie love texture somewhat resembles meat easily substitute recipes call ground beef however family members quite skeptical product prefer leave dishes ultimately look vegetarian meat substitute universal meal substitute
# Original summary: vegetarian approved still
# Predicted summary:  great for camping
#
#
# Review: best gluten free pasta found good texture cook unlike rice pasta cheap think eating gluten free eating
# Original summary: gluten free pasta
# Predicted summary:  great pasta
#
#
# Review: one two cats loves gobbles likes fancy feast unfortunately love ingredients smell looks like chicken human could eat label says feeding cat weruva increase cat lives nine ten thank weruva amazon providing fabulous cat food affordable prices
# Original summary: great cat food
# Predicted summary:  my cat loves this food
#
#
# Review: good taste almost like real thing vanilla inside tastes awesome gotta love poptarts love poptarts
# Original summary: not bad
# Predicted summary:  not the best
#
#
# Review: portable fruit incentive daughter finish meal getting one sucks right also husband dentist course allowed juice fits bill
# Original summary: yr old daughter loves this
# Predicted summary:  my baby loves these
#
#
# Review: got three pack pickles wine woot one hot damn deli flavors arrived house wife sent apo overseas last long super crispy could get enough share pickle goodness highly recommend
# Original summary: awesome
# Predicted summary:  great
#
#
# Review: vegetarian supplementing protein intake whey protein long time really frustrated good competitively priced organic protein mix available skeptical using hemp protein never tried extremely surprised bought chocolate hemp protein mix found taste great also exponentially fiber whey protein taste protein necessarily would call chocolate definitely chocolate like give comparison would say maybe hot cocoa hot cocoa taste similar chocolate nothing like biting chocolate bar overall would highly recommend product
# Original summary: great protein mix
# Predicted summary:  great protein protein alternative
#
#
# Review: sauce looks like orange thousands islands salad dressing tastes similar well hint horseradish smells stronger tastes sauce tangy hot fairly thick refrigerating last quarter sauce flow easily even bottle shaken bottle give maybe servings like orange colored food taste thousand island dressing like sauce
# Original summary: taco bell sauce
# Predicted summary:  taco bell chipotle sauce
#
#
# Review: olive oil far great love tin leave counter rather place cabinet however best put carafe olive oil dispenser quite difficult pour spill taste light bit nutty levels many oils price level price one certainly try
# Original summary: great oil
# Predicted summary:  great oil
#
#
# Review: bought olives small market spain come course less expensive best olives ever worth price
# Original summary: best olives ever
# Predicted summary:  best olives ever
#
#
# Review: sure flaw product coconut water general zico first sipped drink strange saltiness taste passion fruit orange peel barely amazon kind enough refund cost order lesson learned try find sample product buy case
# Original summary: people this refreshing
# Predicted summary:  tastes like medicine
#
#
# Review: really wanted try daughter unfortunately arrived seal broken powder spilled box tried process return get new sealed container item ineligible returns left packaging feedback issue gotten response really hope get replacement stuff cheap gave one star could try update get replacement try used berry flavor think tastes terrible sweet artificial sweet taste daughter eat mixed plain unsweetened apple sauce
# Original summary: was broken on arrival powder all over in box
# Predicted summary:  not bad
#
#
# Review: tried several spicy chai teas far best much better bigelow green chai generous addition honey bit milk wonderful stuff
# Original summary: the best have found
# Predicted summary:  best chai ever
#
#
# Review: apples taste fine since artificial additives sure small average piece inch inch quite pathetic unsatisfying eat multiple pieces notice apple like aromas appreciate crunch also detracts sweetness harder dissolve release sugars pieces dry bad product would buy
# Original summary: why are the pieces so small
# Predicted summary:  not too sweet
#
#
# Review: came across canidae adopted week puppy whose mother transitioned know care properly went local pet store said canidae food use use throughout life simply wet food first weeks going completely dry loved throughout also feed pound goldendoodle loves well definitely great find
# Original summary: all of our dogs love this
# Predicted summary:  my dog loves this food
#
#
# Review: big fan jack link beef jerky especially flavored jerky seen one stores went sale amazon scooped generally beef nuggets style jerky favorite reason beef gets rubbery compared regular style cuts knew diving bag jerky first taste like beef dropped pile debris smokehouse floor smokey meaty ashy tasting thought maybe initial taste continued chew continued eventually swallowed met disgusting taste left mouth four bags remaining sure may give away gag gift holidays literally watch people gag try eat
# Original summary: like beef in an
# Predicted summary:  like beef jerky
#
#
# Review: great idea easy make nutritious way salty cut bag white rice wish would provide spices side could add much need
# Original summary: good idea but too salty
# Predicted summary:  great taste
#
#
# Review: get combing cheerios honey smacks peanuts get actually sounds good unfortunately combination flavors okay great sure even good weird cloying aftertaste cereal feels dry individual pieces large crunchy think okay prefer honey nut cheerios even raisin bran good sign bottom line ymmv replacing box another one
# Original summary: the whole does not equal the of its
# Predicted summary:  not bad
#
#
# Review: lemon crystallized ginger shortbread cookies could possibly better cup tea
# Original summary: yum yum
# Predicted summary:  great taste
#
#
# Review: chips awesome natural flavorful best tasting versatile chips ever tasted work well salsa cheese dips even chips crispy great texture stand thick dips despite jalapeno spicy bland right highly recommend chips
# Original summary: absolutely delicious
# Predicted summary:  best chips ever
#
#
# Review: return refund texture miracle noodle products like eating plastic fishing worms read reviews tried every way possible improve experience eating stuff minutes rinsing par boiling etc buy item stuck com stand behind quality experience take chance losing like
# Original summary: plastic
# Predicted summary:  do not waste your money
#
#
# Review: really good instructions moment pre bake crust mins putting toppings since messed put toppings wet dough quickly adjusted temperature degrees baked pizza longer period time bubbly toppings done delicious suspect main crust may little crispier put toppings prior baking pizza edges crispy main pizza little softer definitely done enjoyable little concerned might happen pizza since pre bake crust problem anxious try second third pizza kits different toppings pre baked crust prior adding toppings pizza
# Original summary: excellent homemade pizza with your added
# Predicted summary:  pizza pizza pancake mix
#
#
# Review: first found hot chocolate natural history places great blend sweetness spice yummy
# Original summary: awesome stuff
# Predicted summary:  excellent
#
#
# Review: looking healthy natural food eat long runs found larabars tried bars fruity sugar crashes larabars cause effect tried many flavors find surprisingly delicious something healthy cinnamon roll cashew cookie apple pie gingersnap favorites far cherry pie cherry snack feel good eating
# Original summary: yummy
# Predicted summary:  great for kids
#
#
# Review: received small box ginger honey crystals fell love great way bump cup hot tea strong would recommend starting small portion ordered two bags thirty packs daughter law wants pack love
# Original summary: fantastic
# Predicted summary:  great product
#
#
# Review: best deal ever almost pieces candy cant get better deal im try flavors
# Original summary: best deal ever
# Predicted summary:  great
#
#
# Review: yum husband loved bacon sampler best bacon ever
# Original summary: bacon
# Predicted summary:  best ever
#
#
# Review: first tried bikram studio pricey place sprouts sell much cheaper love rehydrate body quickly sweaty session yoga
# Original summary: love it
# Predicted summary:  great for moms
#
#
# Review: expiration date bars july already old eat received throw ordered chunky peanut butter think thin bars delicious
# Original summary: to throw them out the chocolate had turned white
# Predicted summary:  not impressed
#
#
# Review: bought tea last year directly special occasions tried lemon rooibus mixes one right balance refreshing hot cold understand people drink day going start glad amazon carrying
# Original summary: the best blend
# Predicted summary:  great tea
#
#
# Review: like flavored coffees want flavoring overwhelm coffee nice balance
# Original summary: nice hint of vanilla
# Predicted summary:  great coffee
#
#
# Review: tinkyada pasta pretty wonderful cannot tell many gluten free pasta brands tried best gross finally found tinkyada never disappointed think absolute favorite tinkyada type also love fettucini lasagna noodles elbows shells
# Original summary: awesome gluten free pasta brand
# Predicted summary:  best pasta ever
#
#
# Review: coffee smooth mild palate strong harsh taste wonderful way relax unwind
# Original summary: wonderful cup of coffee
# Predicted summary:  great coffee
#
#
# Review: walk well even though wonderful partner sometimes left alone quite awhile ease appetite without eating junk great job without junk food
# Original summary: they do the job
# Predicted summary:  great for on the go
#
#
# Review: like kona stronger roast good flavor well hard find cup variety regular stores glad find
# Original summary: one of my favorites
# Predicted summary:  good coffee
#
#
# Review: bars crumble apple filling sour taste awful could eat half bar throwing away never buy brand waste money mention food
# Original summary: this is not the bar for you
# Predicted summary:  not for me
#
#
# Review: seem favorite flavor cats eat real hungry time leave half
# Original summary: cats like it ok
# Predicted summary:  cats love it
#
#
# Review: tri color couscous really good full flavor fun eat love texture cook chicken broth add minced garlic chopped herbs along red pepper flakes end cooking add olive oil makes wonderful side dish highly recommend
# Original summary: fantastic
# Predicted summary:  great for cooking
#
#
# Review: introduced years ago child loved ever since first steaks put fish vegetables love sprinkle freash steamed really good ton ingredients natural
# Original summary: excellent high quality seasoning with great flavor
# Predicted summary:  great rub
#
#
# Review: bought two orders twenty pounds red swedish fish little stunning see little guys quantity bagging little bags silver ribbons daughter upcoming wedding swedish man hence massive purchase anyway arrived promptly packaged securely delicious chewy cheapest place found thanks
# Original summary: an amazing amount of fish
# Predicted summary:  great prunes
#
#
# Review: may well best thing since sliced bread like egg noodles probably like pasta quite like regular fettuccine close enough weight watchers points like diet food little different
# Original summary: awesome
# Predicted summary:  great taste
#
#
# Review: great price gobbled lemon toffee chocolate strawberry tried lemon wulong tea ick guess try better tasting tea noticed taste usual also tried strawberry carbonated water suggestion recipes hcg protocol bad definitely something gotta get use taste know product stevia products natural taste mentally affect aspartame splenda man made sweeteners plain bad us taste stevita products remind man made sweeteners ick actually little better luck nu stevia powder long careful amount example use smoothies packet oz smoothie rating taste taste
# Original summary: after taste
# Predicted summary:  great tasting
#
#
# Review: cannot find store went find line found best
# Original summary: the best
# Predicted summary:  great product
#
#
# Review: star rating scale works water perfect robust butter taste would believe butter including clarified butter little butter taste rate real butter products microwave popcorn buttery point going back scale rate butter taste around far intense wabash buttery topping unfortunately taste like butter meaning little buttery taste given rating actual butter like product recommend making buying clarified butter instead save money since taste search continues good buttery topping
# Original summary: it is all about flavor
# Predicted summary:  not bad
#
#
# Review: organic price unbeatable good enough eat chia seeds feel good
# Original summary: chia seeds with price
# Predicted summary:  great price
#
#
# Review: popchips delicious bought variety pack love salt pepper though flavors good chips high sodium nice healthy alternative grease salt laden fried potato chips expect traditional potato chip even pressed chip like pringles different delicious ounce bag contains calories daily salt bag says start potato add little heat pressure pop well quite ingredients list natural potato ingredients safflower oil sunflower oil rice flour sea salt need gluten free gluten free made equipment shared wheat
# Original summary: salt and pepper
# Predicted summary:  great chips
#
#
# Review: give dog go thing tried stop everything start munching
# Original summary: my dog loves these
# Predicted summary:  my dog loves these
#
#
# Review: bars ok smaller photo box need little something tide next meal could help maintain lose weight tastiest things
# Original summary: these are ok
# Predicted summary:  tasty but not great
#
#
# Review: wife eat really spicy food love chips since pretty spicy lot spicier spicy salsa would reccommend people cannot eat anything spicier wish beef jerky spicy
# Original summary: spicy stuff
# Predicted summary:  great taste
#
#
# Review: trying several packages signature blend different product codes found discs defective grounds ended bottom cup rest spewed coffeemaker notified gevalia month ago offered explanation solution problem problem brand disc gevalia blends extremely frustrating considering paying extra gevalia name would recommend maxwell house seattle best far superior discs grounds bottom cup
# Original summary: defective discs
# Predicted summary:  not worth the money
#
#
# Review: bought product many months ago loved longer buying brand doubled price bought originally buy another brand
# Original summary: the price doubled
# Predicted summary:  great product
#
#
# Review: buy online always burnt fur person loves wrote company said nothing wrong compared others definitely burnt
# Original summary: burnt
# Predicted summary:  not for me
#
#
# Review: ex pat uk tea buy hot tea really try see
# Original summary: cup of tea
# Predicted summary:  great tea
#
#
# Review: love metromint products never really liked drinking water metromint much refreshing regular water add calories chemicals diet peppermint far flavor make tastes kind like drinking water chewing strong peppermint gum keep desk work need refrigerated still feels cool mint wonderful product mint lovers like strong mint flavor fruity quite strong
# Original summary: the classic mint water
# Predicted summary:  best ever
#
#
# Review: people read ingredients zico made concentrate drink vitacoco one ingredient natural coconut water zico go
# Original summary: pure premium think not
# Predicted summary:  tastes like plastic
#
#
# Review: healthy tasty portable packets great go perfect gym bag cannot tote around fresh next best option pear mango flavor texture smooth applesauce recently packed work trip good way add little something healthy hotel fast food often dominate comes business travel
# Original summary: great gym snack for adults
# Predicted summary:  great for the price
#
#
# Review: veggie jerky fantastic hot spicy favorite pretty good true bit less protein variety significantly fiber note definite spice overwhelming definitely flavor implies
# Original summary: spicy satisfying
# Predicted summary:  spicy and spicy
#
#
# Review: good plant avid gardener know pick produce olives floral fragrant plant
# Original summary: careful
# Predicted summary:  not what expected
#
#
# Review: impressed easy use much better one buy keurig great company buy go reorder
# Original summary: great item great customer service
# Predicted summary:  great product
#
#
# Review: cannot popcorn kernels products tried oily contain trans fats product best tasting oily flavor trans fats highly recommend makes living without popcorn easy
# Original summary: the best
# Predicted summary:  great northern popcorn
#
#
# Review: decided time start feeding senior cat wet food diet tendency turn nose healthy choices absolutely devoured one several months later still loving practically licks bowl clean made world difference energy level coat shiny cut amount waste litter box ingredients natural vet recommended one top choices wet food cat food smaller size chunks lot gravy pouch easy rip open cut highly recommend healthy choice finicky feline
# Original summary: excellent choice even for the finicky
# Predicted summary:  my cat loves it
#
#
# Review: reasonably priced excellent quality dark taste nuts salty
# Original summary: fresh and consistently tasty
# Predicted summary:  good chips
#
#
# Review: really like tea hard find thrilled find flavor wonderful grassy like green teas
# Original summary: wonderful flavor
# Predicted summary:  great tea
#
#
# Review: lipton tea honey go iced tea mix packets convenient way drink healthy go box contains ten packets pour bottle water instant green tea yummy taste perfect hot summer day sampled strawberry acai flavor thought delicious tempted try flavors like peach apricot blackberry pomegranate like best contain aspartame like flavor packets market today calories per serving like sweetened honey made real tea leaves real fruit flavors
# Original summary: refreshingly sweet taste
# Predicted summary:  great tasting tea
#
#
# Review: hate coffee love hour energy also hate paying bucks stores economical usually put one tsa approved quart size bag business trips meetings
# Original summary: best price anywhere
# Predicted summary:  great product
#
#
# Review: buying blue dog bakery treats almost years quality really great number years last years gotten cases burnt cookies company replaced latest purchase back ones liked past like use human grade ingredients dogs love wish could buy boxes small cookies small dogs break larger ones smaller pieces
# Original summary: great dog treats
# Predicted summary:  my dog loves these
#
#
# Review: far best corn chips ever going send case gift would wonderful party
# Original summary: wow
# Predicted summary:  best chips ever
#
#
# Review: nuts plump fat salty seemed bit dry fresh would liked purchase amount feel fresh nuts uniquely flavorful signature taste seemed many nuts lovely indistinguishable one another
# Original summary: plump and fat
# Predicted summary:  good but not great
#
#
# Review: really enjoy brand tea put comment perspective coffee drinker care many teas die hard tea drinker may appreciate flavor tea like add little honey could drink tea hours also makes great ice tea
# Original summary: best tea around
# Predicted summary:  great tea
#
#
# Review: found coconut water almost tasteless like water slight coconut flavor coconut waters quite expensive like coconut flavor true complaints others prefer zico
# Original summary: ok but not my favorite
# Predicted summary:  not so good
#
#
# Review: good organic hollandaise sauce non organic store bought homeade version much noticeable lemon taste non organic store bought versions tried purchased non organic store bought version decided purchase case amazon brand remember buying whole foods reason noticed difference taste
# Original summary: different taste than non organic store bought version
# Predicted summary:  great taste
#
#
# Review: currently working afghanistan counterparts soldiers love flavor freshness variety bag delivered two weeks faster estimated highly recommend
# Original summary: delicious beans
# Predicted summary:  great product
#
#
# Review: elderly dog hip joint problems taking zuke hip action dog treats little month huge difference loves way treats taste best walking ease easier time stairs yesterday broke full first time ages followed size listed back package surprised results love zuke
# Original summary: love it
# Predicted summary:  great for training
#
#
# Review: taste tested foods pretty good organic like feed baby earth best
# Original summary: its better option than gerber
# Predicted summary:  baby loves it
#
#
# Review: switched green mountain breakfast blend able get black tiger super saver item real disappointment weak certainly something would want breakfast blend
# Original summary: disappointed after drinking black tiger
# Predicted summary:  not bad
#
#
# Review: dagoba dark chocolate bar taste good taste like artificial chocolate throw away learn live
# Original summary: chocolate bar
# Predicted summary:  not so good
#
#
# Review: originally started enfamil newborn premium colic indigestion could keep whole bottle helped greatly create thicker mix difficult slow medium nipples bad fast nipples works us
# Original summary: lot less spit up
# Predicted summary:  great for
#
#
# Review: sorry could drink people call old world coffee call old cheap hotel coffee soooo dark color like smell pleasant tastes like bad coffee made terrible tap water find inside cheap hotel sorry rather drink coffee drink one star
# Original summary: taste like cheap coffee
# Predicted summary:  terrible
#
#
# Review: name biscuits speaks great first thing morning without tea cofee meals
# Original summary: digestive indeed
# Predicted summary:  great tea
#
#
# Review: one best instant noodle ever warned spicy put spice red chilly pack flavor kind seafood flavor seems best
# Original summary: one of the best instant noodle have ever had
# Predicted summary:  spicy and spicy
#
#
# Review: never tried red chips sure would getting pleasantly surprised great flavor texture
# Original summary: yum
# Predicted summary:  best chips ever
#
#
# Review: product works great way easier get syrup purchase great price
# Original summary: smooth
# Predicted summary:  great product
#
#
# Review: tried variety larabar food bars one favorites tart cherry flavor intense bars quite satisfying nice eat something actually good tastes good
# Original summary: great snack bar
# Predicted summary:  delicious
#
#
# Review: tried many cups greatest problem cups many weak never liked strong cup coffee know one make grow chest hair tried many flavored cups milder coffee reason however glad found vanilla cup actually taste vanilla coffee cup coffee cup enjoyed sample much bought boxes ct addition hazelnut hope hazelnut good
# Original summary: great french vanilla cup
# Predicted summary:  good coffee
#
#
# Review: love taco bell sauce right says natural smokey flavor ingredients comes across heavy dose liquid smoke use way much flavor left worse chipotle flavoring felt powdery like mixed well kind like grit
# Original summary: smoky flavor too much
# Predicted summary:  not so good
#
#
# Review: one best tasting cocoa mix found easy make one cup cup clean grounds use cup lids
# Original summary: cocoa cups
# Predicted summary:  great cocoa
#
#
# Review: drink days feeling sluggish definitely gives pep crazy taste love effects
# Original summary: love it
# Predicted summary:  best drink ever
#
#
# Review: purchased item larger great mango pulp cooking desserts etc one six cans huge dent would obvious pack placed shipping box items packaged well see could happened shipping since outside box signs damage much hassle return cans one damaged need one mango cupcakes making weekend due dented probably thrown away cannot tell good bad probably purchase item amazon buy locally find
# Original summary: good product but huge dent in of cans
# Predicted summary:  great product poor packaging
#
#
# Review: tried making recipes books use soy almond flour carbquik makes biscuits even son says taste like good nobody else ate muffins price netrition much lower bought carbquik also bought flour tried yet supposed near substitute real flour biscuits claim carbs guess one could even eat atkins diet phase
# Original summary: best tasting low carb flour substitute
# Predicted summary:  not worth the money
#
#
# Review: honey stingers great used handful times runs lasting hour seem provide much needed energy easy chew taste great stick teeth make extra thirsty packet small enough portable really like ingredients healthy enough however see different organic fruit snacks get much cheaper multi pack local wholesale club ingredients nutrition information virtually identical reason gave stars
# Original summary: great but special am not so sure
# Predicted summary:  great taste but pricey
#
#
# Review: coffee distinct flavor aroma perfect mix chocolate rasberry raspberry natural flavor great even made larger cup serving ice
# Original summary: great iced or hot
# Predicted summary:  best chocolate ever
#
#
# Review: best saffron ever tried smell color taste best ever buy saffron ever travel iran never seen anything like buy knowing getting real thing
# Original summary: the best saffron have ever used
# Predicted summary:  best have found
#
#
# Review: love spicy food live find spicy ramen korean said spiciest noodles america take seriously going buy ramen online insisted try sent box amazon wow really spicy like add kimchi egg mine personally put chicken lamb shrimp white fish beef suggest want meat add bit oil pot seasoning packet cook like first almost cooked add water cook noodles separate drain add noodles bowl top broth meat veggie little extra work really worth time
# Original summary: mm spicy
# Predicted summary:  great taste
#
#
# Review: given pack coffee gift sitting around quite decided try without doubt one best coffees tasted smooth flavorful would highly recommend ordered supply amazon vacuum packed may try decaf version see tastes
# Original summary: some of the best coffee have had
# Predicted summary:  best ever
#
#
# Review: ordered kups thought making kups fit together without big production lids fit water comes top brewer lid well kcup big mess wanted want return get refund donna
# Original summary: kups ordered from amazon
# Predicted summary:  cups
#
#
# Review: like espresso probably like coffee taste strong bold mildly sweetened one contains calories mg caffeine yikes lot caffeine like coffee strong drinking fyi product denmark
# Original summary: packs strong punch
# Predicted summary:  strong coffee
#
#
# Review: definitely keep stock tried sample long time acid reflux sufferer pleased find rich mild coffee rich flavorful mild enough irritate stomach perfect told cut back strong coffee
# Original summary: no heartburn here thank you
# Predicted summary:  great coffee
#
#
# Review: cake little smaller thought delicious husband enjoyed much ordering christmas
# Original summary: awesome rum cake
# Predicted summary:  great candy
#
#
# Review: got oil local grocery surprised first tasted almost seems bit spicy love olive oils great one would excellent use directly food opposed cooking great salad dressing add bit steamed veggies awesome dip crusty bread etc paid today heb size bottle
# Original summary: fabulous different taste
# Predicted summary:  best ever
#
#
# Review: use low sodium seasoning blend time add dish end preparation punch flavor roasted garlic milder fresh worry usual raw garlic flavor makes perfect sprinkle soups salads baked potatoes dips etc onion red green peppers additional ingredients still excellent product worth new price reordering
# Original summary: adds great punch of flavor
# Predicted summary:  great seasoning
